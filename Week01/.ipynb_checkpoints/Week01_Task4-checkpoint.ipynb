# %% [markdown]
# # 栗まんじゅう問題
# 漫画ドラえもんには「バイバイン」という道具が登場する、2のn乗に関する有名なエピソード[1]があります。
#
# [1] 藤子・Ｆ・不二雄(1979)『ドラえもん（１７）』小学館.
#
# 「バイバイン」は薬品で、これを振掛けるとその物体は5分ごとに倍に増えるという働きがあります。作中では栗まんじゅうを増やしますが、食べきれなくなったためロケットを使い宇宙に捨てました。
#
# ここで度々話題になるのが、栗まんじゅうはその後宇宙でどのように増えていくのかについてです。様々な議論がされていますが、今回は単純に栗まんじゅうの体積がどう増えるかを計算してみましょう。

# %% [markdown]
# ## 【問題】栗まんじゅうが太陽系を覆う日
# 1個の栗まんじゅうにバイバインを振りかけた場合、太陽系が栗まんじゅうで覆われるのは何分後でしょうか。これを計算するプログラムを作成してください。
#
# 栗まんじゅうや太陽系の体積を調査した上で仮定して計算してください。栗まんじゅうの隙間や重力などは考えず、問題を単純化して構いません。
#
# ボールにバイバインを振りかけた時、東京ドームが一杯になる時間など他の状況にも適用できるような汎用的なプログラムを作成してください。また、グラフを表示するなど分かりやすいノートブックを作成してください。

# %%
import numpy as np 

kurimanju_num = 1 #初期栗饅頭個数
KURIMANJU_Vol = 0.0001 # 栗饅頭を１００立方センチメートルと過程

#太陽系の体積
solar_system_r = 1.49007e+16 #太陽系半径
solar_system_vol = 4/3*np.pi*(solar_system_r**3) #太陽系を球と仮定し体積計算

#栗饅頭のバイバイン
kurimanju_vol = KURIMANJU_Vol
minute = 0
while kurimanju_vol < solar_system_vol:
    kurimanju_vol *= 2
    minute += 5

print("栗饅頭が太陽系を埋め尽くすには{}分かかります".format(minute))
# Out:
# 栗饅頭が太陽系を埋め尽くすには885分かかります

# %% [markdown]
# ## 東京ドームが一杯になる時間

# %%
#野球ボールの体積
baseball_r = 0.725/2 #半径
BASEBALL_Vol = 4/3*np.pi*(baseball_r**3) #体積計算

# 引数に体積を入力すると、野球ボールが入力した体積を埋め尽くすまでの時間を返してくれる関数
def computse_baseball_min(space):
    baseball_vol = BASEBALL_Vol 
    minute = 0
    while baseball_vol < space:
        baseball_vol *= 2
        minute += 5
        return print("埋め尽くすのに必要な時間は{}分です。".format(minute))

# %% [markdown]
# [東京ドーム体積＝124万m3](https://ja.wikipedia.org/wiki/東京ドーム_(単位)),
# [野球ボールの直径(72.5cm)](https://www.sizekensaku.com/sports/baseball_ball.html)

# %%
#東京ドームを埋め尽くそうの巻
print("→東京ドームを",end="")
computse_baseball_min(12400)
# Out:
# →東京ドームを埋め尽くすのに必要な時間は5分です。

# %% [markdown]
# ## 東京ドームが一杯になる時間-グラフ作成-
# 引数に体積を入力すると、野球ボールが入力した体積を埋め尽くすまでの時間と体積の関係を返してくれる関数

# %%
def computse_baseball(space):
    #野球ボールの体積
    baseball_r = 0.725/2 #半径
    BASEBALL_Vol = 4/3*np.pi*(baseball_r**3) #体積計算

    baseball_vol = BASEBALL_Vol 
    minute = 0
    
    min_array = []
    baseball_vol_array = [baseball_vol]
    while baseball_vol < space:
        baseball_vol *= 2
        baseball_vol_array.append(baseball_vol)
        minute += 5
        min_array.append(minute)
        
        return

# %%
#リスト作成
baseball_num = [1] #ボール個数
baseball_v_a = [BASEBALL_Vol] #ドームを埋め尽くす推移
minute = [0] #経過時間

#初期化
baseball_vol = BASEBALL_Vol

#東京ドームの体積
dorm_space = 124

while baseball_vol < dorm_space:
    baseball_vol *= 2
    baseball_num.append(baseball_vol)
    baseball_v_a.append(baseball_v_a[-1]+baseball_vol)
    
#グラフ作成
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (8,10))

#ボール個数の推移グラフ表示
ax1.plot(baseball_num)
ax1.set_title("Rice for the day")
ax1.set_xlabel('Days')
ax1.set_ylabel('Amount of rice')

#ドームを埋め尽くす推移グラフ表示
ax2.plot(baseball_v_a)
ax2.set_title("Cumulative number of rice to date")
ax2.set_xlabel('Days')
ax2.set_ylabel('Amount of rice')

fig.show()
